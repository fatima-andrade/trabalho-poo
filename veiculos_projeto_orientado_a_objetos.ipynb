# %% [markdown]
# <a href="https://colab.research.google.com/github/fatima-andrade/trabalho-poo/blob/nova-ramifica%C3%A7%C3%A3o/veiculos_projeto_orientado_a_objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile veiculo.py
class Veiculo:
    def __init__(self, marca, modelo, ano, placa):
        self.marca = marca
        self.modelo = modelo
        self.ano = ano
        self.placa = placa

    def exibir_informacoes(self):
        print(f"Marca: {self.marca}")
        print(f"Modelo: {self.modelo}")
        print(f"Ano: {self.ano}")
        print(f"Placa: {self.placa}")

    def acelerar(self):
        print(f"O {self.modelo} está acelerando...")

    def frear(self):
        print(f"O {self.modelo} está freando...")
# Out:
# Overwriting veiculo.py

# %%
# %%writefile carro.py
from veiculo import Veiculo

class Carro(Veiculo):
    def __init__(self, marca, modelo, ano, placa, numero_portas):
        super().__init__(marca, modelo, ano, placa)
        self.numero_portas = numero_portas

    def acelerar(self):
        print(f"O carro {self.modelo} está acelerando com o motor a combustão.")

    def abrir_porta(self):
        print(f"A porta do carro {self.modelo} foi aberta.")
# Out:
# Overwriting carro.py

# %%
# %%writefile moto.py
from veiculo import Veiculo

class Moto(Veiculo):
    def __init__(self, marca, modelo, ano, placa, tipo):
        super().__init__(marca, modelo, ano, placa)
        self.tipo = tipo

    def acelerar(self):
        print(f"A moto {self.modelo} está acelerando com mais agilidade!")

    def empinar(self):
        print(f"A moto {self.modelo} está empinando!")
# Out:
# Overwriting moto.py

# %%
# %%writefile main.py
from carro import Carro
from moto import Moto

def menu():
    carro1 = Carro("Toyota", "Corolla", 2020, "ABC-1234", 4)
    moto1 = Moto("Honda", "CB500", 2021, "XYZ-5678", "Esportiva")

    while True:
        print("\n---- Menu ----")
        print("1. Exibir informações do carro")
        print("2. Exibir informações da moto")
        print("3. Acelerar carro")
        print("4. Acelerar moto")
        print("5. Sair")

        opcao = input("Escolha uma opção: ")

        if opcao == "1":
            carro1.exibir_informacoes()
        elif opcao == "2":
            moto1.exibir_informacoes()
        elif opcao == "3":
            carro1.acelerar()
        elif opcao == "4":
            moto1.acelerar()
        elif opcao == "5":
            print("Saindo...")
            break
        else:
            print("Opção inválida!")

menu()
# Out:
# Overwriting main.py

# %%
# !python3 main.py
# Out:
# ---- Menu ----
# 1. Exibir informações do carro
# 2. Exibir informações da moto
# 3. Acelerar carro
# 4. Acelerar moto
# 5. Sair
# Escolha uma opção: 1
# Marca: Toyota
# Modelo: Corolla
# Ano: 2020
# Placa: ABC-1234
#
# ---- Menu ----
# 1. Exibir informações do carro
# 2. Exibir informações da moto
# 3. Acelerar carro
# 4. Acelerar moto
# 5. Sair
# Escolha uma opção: 2
# Marca: Honda
# Modelo: CB500
# Ano: 2021
# Placa: XYZ-5678
#
# ---- Menu ----
# 1. Exibir informações do carro
# 2. Exibir informações da moto
# 3. Acelerar carro
# 4. Acelerar moto
# 5. Sair
# Escolha uma opção: 3
# O carro Corolla está acelerando com o motor a combustão.
#
# ---- Menu ----
# 1. Exibir informações do carro
# 2. Exibir informações da moto
# 3. Acelerar carro
# 4. Acelerar moto
# 5. Sair
# Escolha uma opção: 4
# A moto CB500 está acelerando com mais agilidade!
#
# ---- Menu ----
# 1. Exibir informações do carro
# 2. Exibir informações da moto
# 3. Acelerar carro
# 4. Acelerar moto
# 5. Sair
# ...

# %%
# %%writefile heranca_polimorfismo.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# class Veiculo {
# public:
#     string marca;
#     string modelo;
#
#     virtual void exibir_dados() {
#         cout << "Veículo: " << marca << " " << modelo << endl;
#     }
# };
#
# class Carro : public Veiculo {
# public:
#     string cor;
#
#     void exibir_dados() override {
#         cout << "Carro: " << marca << " " << modelo << ", Cor: " << cor << endl;
#     }
# };
#
# int main() {
#     Veiculo veiculo;
#     veiculo.marca = "Toyota";
#     veiculo.modelo = "Corolla";
#
#     Carro carro;
#     carro.marca = "Honda";
#     carro.modelo = "Civic";
#     carro.cor = "Preto";
#
#     Veiculo* ptr_veiculo;
#
#     ptr_veiculo = &veiculo;
#     ptr_veiculo->exibir_dados();  // Saída: Veículo: Toyota Corolla
#
#     ptr_veiculo = &carro;
#     ptr_veiculo->exibir_dados();  // Saída: Carro: Honda Civic, Cor: Preto
#
#     return 0;
# }
# Out:
# Overwriting heranca_polimorfismo.cpp

# %%
# !g++ -o heranca_polimorfismo heranca_polimorfismo.cpp

# %%
# !./heranca_polimorfismo
# Out:
# Veículo: Toyota Corolla
# Carro: Honda Civic, Cor: Preto
